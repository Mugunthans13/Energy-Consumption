# %% [markdown]
# # Description:
#
# This dataset is designed for predicting energy consumption based on various building features and environmental factors.
# It contains data for multiple building types, square footage, the number of occupants, appliances used, average temperature, and the day of the week.
# The goal is to build a predictive model to estimate energy consumption using these attributes.
# The dataset can be used for training machine learning models such as linear regression to forecast energy needs based on the building's characteristics.
# This is useful for understanding energy demand patterns and optimizing energy consumption in different building types and environmental conditions.

# %% [markdown]
# # About this file:
#
# This file contains the testing dataset, which is used to evaluate the performance of the trained machine learning model.
#
# 1) BuildingType: Categorical feature representing the type of building.
# 2) SquareFootage: Numeric feature representing the total square footage of the building.
# 3) NumberOfOccupants: Numeric feature indicating the number of people occupying the building.
# 4) AppliancesUsed: Numeric feature representing the number of appliances used in the building.
# 5) AverageTemperature: Numeric feature representing the average temperature of the building or climate area (in Celsius).
# 6) DayOfWeek: Categorical feature representing whether the data point corresponds to a weekday or weekend.
# 7) EnergyConsumption: Numeric target variable representing the energy consumption of the building in kWh (kilowatt-hours).

# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\JAGATHARATCHAGAN K\Downloads\Energy Consumption\Energy Consumption\train_energy_data.xlsx")
data
# Out:
#     BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0    Residential           7063                 76              10
# 1     Commercial          44372                 66              45
# 2     Industrial          19255                 37              17
# 3    Residential          13265                 14              41
# 4     Commercial          13375                 26              18
# ..           ...            ...                ...             ...
# 995  Residential          14419                 68              44
# 996   Industrial          12194                  7              22
# 997   Commercial          39562                 88              20
# 998  Residential           8348                 67              37
# 999   Commercial          15813                 57              11
#
#      AverageTemperature DayOfWeek  EnergyConsumption
# 0                 29.84   Weekday            2713.95
# 1                 16.72   Weekday            5744.99
# ...

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.dtypes
# Out:
# BuildingType           object
# SquareFootage           int64
# NumberOfOccupants       int64
# AppliancesUsed          int64
# AverageTemperature    float64
# DayOfWeek              object
# EnergyConsumption     float64
# dtype: object

# %%
data.isna().sum()
# Out:
# BuildingType          0
# SquareFootage         0
# NumberOfOccupants     0
# AppliancesUsed        0
# AverageTemperature    0
# DayOfWeek             0
# EnergyConsumption     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BuildingType        1000 non-null   object
#  1   SquareFootage       1000 non-null   int64
#  2   NumberOfOccupants   1000 non-null   int64
#  3   AppliancesUsed      1000 non-null   int64
#  4   AverageTemperature  1000 non-null   float64
#  5   DayOfWeek           1000 non-null   object
#  6   EnergyConsumption   1000 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns

data.hist(figsize=(10,8),bins=15)
plt.show()

# %%
plt.subplots(figsize = (20,15))
plt.subplot(2,2,1)
sns.boxplot(x='EnergyConsumption', y='SquareFootage', data=data)
plt.subplot(2,2,2)
sns.boxplot(x='EnergyConsumption', y='NumberOfOccupants', data=data)
plt.subplot(2,2,3)
sns.boxplot(x='EnergyConsumption', y='AppliancesUsed', data=data)
plt.subplot(2,2,4)
sns.boxplot(x='EnergyConsumption', y='AverageTemperature', data=data)
plt.show()

# %%
sns.lmplot(x='EnergyConsumption', y='SquareFootage', data=data)
plt.show()

# %%
sns.lmplot(x='EnergyConsumption', y='AppliancesUsed', data=data)
plt.show()

# %%
sns.lmplot(x='EnergyConsumption', y='AverageTemperature', data=data)
plt.show()

# %%
sns.lmplot(x='EnergyConsumption', y='NumberOfOccupants', data=data)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['BuildingType'] = le.fit_transform(data['BuildingType'])

# %%
data
# Out:
#      BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0               2           7063                 76              10
# 1               0          44372                 66              45
# 2               1          19255                 37              17
# 3               2          13265                 14              41
# 4               0          13375                 26              18
# ..            ...            ...                ...             ...
# 995             2          14419                 68              44
# 996             1          12194                  7              22
# 997             0          39562                 88              20
# 998             2           8348                 67              37
# 999             0          15813                 57              11
#
#      AverageTemperature DayOfWeek  EnergyConsumption
# 0                 29.84   Weekday            2713.95
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['DayOfWeek'] = le.fit_transform(data['DayOfWeek'])

# %%
data
# Out:
#      BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0               2           7063                 76              10
# 1               0          44372                 66              45
# 2               1          19255                 37              17
# 3               2          13265                 14              41
# 4               0          13375                 26              18
# ..            ...            ...                ...             ...
# 995             2          14419                 68              44
# 996             1          12194                  7              22
# 997             0          39562                 88              20
# 998             2           8348                 67              37
# 999             0          15813                 57              11
#
#      AverageTemperature  DayOfWeek  EnergyConsumption
# 0                 29.84          0            2713.95
# ...

# %%
corr = data.corr()
corr
# Out:
#                     BuildingType  SquareFootage  NumberOfOccupants  \
# BuildingType            1.000000       0.041292          -0.002462
# SquareFootage           0.041292       1.000000           0.033379
# NumberOfOccupants      -0.002462       0.033379           1.000000
# AppliancesUsed         -0.025035      -0.013478           0.023646
# AverageTemperature      0.038325       0.027273           0.014122
# DayOfWeek              -0.025229       0.011354           0.014296
# EnergyConsumption      -0.202358       0.774873           0.354485
#
#                     AppliancesUsed  AverageTemperature  DayOfWeek  \
# BuildingType             -0.025035            0.038325  -0.025229
# SquareFootage            -0.013478            0.027273   0.011354
# NumberOfOccupants         0.023646            0.014122   0.014296
# AppliancesUsed            1.000000           -0.062870  -0.009046
# AverageTemperature       -0.062870            1.000000  -0.011106
# ...

# %%
sns.heatmap(data.corr().round(2),annot=True)
plt.show()

# %%
sns.pairplot(data=data)
plt.show()

# %%
x_train =data.iloc[:,:-1]
x_train
# Out:
#      BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0               2           7063                 76              10
# 1               0          44372                 66              45
# 2               1          19255                 37              17
# 3               2          13265                 14              41
# 4               0          13375                 26              18
# ..            ...            ...                ...             ...
# 995             2          14419                 68              44
# 996             1          12194                  7              22
# 997             0          39562                 88              20
# 998             2           8348                 67              37
# 999             0          15813                 57              11
#
#      AverageTemperature  DayOfWeek
# 0                 29.84          0
# 1                 16.72          0
# 2                 14.30          1
# ...

# %%
y_train = data['EnergyConsumption']
y_train
# Out:
# 0      2713.95
# 1      5744.99
# 2      4101.24
# 3      3009.14
# 4      3279.17
#         ...
# 995    3661.21
# 996    3546.34
# 997    5147.21
# 998    3244.98
# 999    3423.63
# Name: EnergyConsumption, Length: 1000, dtype: float64

# %%
test = pd.read_excel(r"C:\Users\JAGATHARATCHAGAN K\Downloads\Energy Consumption\Energy Consumption\test_energy_data.xlsx")
test
# Out:
#    BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0   Residential          24563                 15               4
# 1    Commercial          27583                 56              23
# 2    Commercial          45313                  4              44
# 3   Residential          41625                 84              17
# 4   Residential          36720                 58              47
# ..          ...            ...                ...             ...
# 95   Commercial           1161                 81              11
# 96  Residential          37943                 50              23
# 97   Commercial           1558                 27              29
# 98   Industrial           2145                 56              12
# 99  Residential          42414                 72              24
#
#     AverageTemperature DayOfWeek  EnergyConsumption
# 0                28.52   Weekday            2865.57
# 1                23.07   Weekend            4283.80
# ...

# %%
test_le = LabelEncoder()
test['BuildingType']=test_le.fit_transform(test['BuildingType'])

# %%
test_le = LabelEncoder()
test['DayOfWeek']=test_le.fit_transform(test['DayOfWeek'])

# %%
test
# Out:
#     BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0              2          24563                 15               4
# 1              0          27583                 56              23
# 2              0          45313                  4              44
# 3              2          41625                 84              17
# 4              2          36720                 58              47
# ..           ...            ...                ...             ...
# 95             0           1161                 81              11
# 96             2          37943                 50              23
# 97             0           1558                 27              29
# 98             1           2145                 56              12
# 99             2          42414                 72              24
#
#     AverageTemperature  DayOfWeek  EnergyConsumption
# 0                28.52          0            2865.57
# 1                23.07          1            4283.80
# ...

# %%
x_test = test.iloc[:,:-1]
x_test
# Out:
#     BuildingType  SquareFootage  NumberOfOccupants  AppliancesUsed  \
# 0              2          24563                 15               4
# 1              0          27583                 56              23
# 2              0          45313                  4              44
# 3              2          41625                 84              17
# 4              2          36720                 58              47
# ..           ...            ...                ...             ...
# 95             0           1161                 81              11
# 96             2          37943                 50              23
# 97             0           1558                 27              29
# 98             1           2145                 56              12
# 99             2          42414                 72              24
#
#     AverageTemperature  DayOfWeek
# 0                28.52          0
# 1                23.07          1
# 2                33.56          0
# ...

# %%
y_test = test.iloc[:,-1]
y_test
# Out:
# 0     2865.57
# 1     4283.80
# 2     5067.83
# 3     4624.30
# 4     4820.59
#        ...
# 95    3010.81
# 96    4248.49
# 97    2843.60
# 98    3348.39
# 99    4722.59
# Name: EnergyConsumption, Length: 100, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr = lr.predict(x_test)
print(y_pred_lr)
print(r2_score(y_test,y_pred_lr))
# Out:
# [3078.74714138 4534.96464097 5322.15445607 4888.70817968 5065.12736249
#  4514.23975894 4652.56075913 2599.9176507  3447.00270851 4625.13281556
#  5426.57903354 3275.70315395 3882.86940426 5248.1276996  3961.93421307
#  2875.9915805  4484.85337966 3527.41592309 3615.61594752 4320.92910596
#  3867.58356833 5193.52281597 4604.33749729 4160.1401863  5011.12831485
#  4451.23081937 4516.02296162 4742.99547758 4234.91106632 3998.58529659
#  4264.64504717 4844.91780368 6309.94122459 3739.9979548  3823.0026194
#  4241.60874902 4431.29589075 3389.23839649 2614.75157303 5875.02170247
#  5048.29307006 4085.02004624 5145.33239623 4684.2340433  4514.32786588
#  3744.68440828 4654.90691377 2951.30628519 3382.13229596 4378.61970056
#  3386.80734762 4536.34435661 5536.70333944 3314.31919179 3086.54856922
#  4508.92615317 3231.97672148 5246.59307063 4940.68065607 3105.56969601
#  2569.85107029 4660.47827086 3807.5034176  2927.56013838 5605.58258465
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
#from sklearn.metrics import r2_score
dtr = DecisionTreeRegressor(criterion='absolute_error',random_state=8)
dtr.fit(x_train,y_train)
y_pred_dtr = dtr.predict(x_test)
print(y_pred_dtr)
print(r2_score(y_test,y_pred_dtr))
# Out:
# [3249.48 3985.8  5260.26 5031.14 4922.82 4988.57 4454.51 2417.11 4331.04
#  5088.21 5390.61 3835.   4269.02 4682.44 4158.47 2406.04 4947.78 4015.3
#  3229.31 4245.53 4658.38 4802.21 4805.17 4158.47 5348.31 3901.38 4642.27
#  4449.57 3964.54 3889.08 4881.83 4730.23 5867.13 3845.57 3837.78 4073.01
#  3952.58 4141.78 2631.16 5590.7  4729.67 3773.61 4698.47 4274.73 4197.59
#  3229.31 5518.13 2921.01 2728.63 3811.73 3064.11 4454.51 4978.71 3392.31
#  3514.09 5327.65 2989.05 5177.22 4520.19 2921.01 2631.16 4945.09 3741.64
#  2724.62 4828.19 5407.04 4261.05 3815.61 2870.44 3723.56 3953.1  4158.47
#  4946.38 4518.12 4008.78 3299.75 4496.55 4944.4  3279.51 4417.34 3459.59
#  4890.31 4233.24 5842.72 4172.54 4507.73 5017.45 2998.57 5088.21 4212.08
#  3484.46 4172.54 3901.38 4209.18 4141.78 2839.18 4090.41 2875.48 3407.54
#  4649.88]
# 0.9225979501111521

# %%
from sklearn.tree import DecisionTreeRegressor
#from sklearn.metrics import r2_score
dtr = DecisionTreeRegressor(criterion='absolute_error',random_state=8)
dtr.fit(x_train,y_train)
y_pred_dtr = dtr.predict(x_train)
print(y_pred_dtr)
print(r2_score(y_train,y_pred_dtr))
# Out:
# [2713.95 5744.99 4101.24 3009.14 3279.17 4687.67 5526.83 4116.32 5841.65
#  3419.13 4318.61 5206.34 4070.21 2571.98 5031.14 3891.12 3362.42 5672.37
#  3563.67 3080.67 4993.7  4750.37 4134.35 3930.14 4411.53 4812.15 3342.21
#  5754.96 3566.01 3409.14 4230.09 4700.42 3991.89 4190.25 2205.2  4483.83
#  2733.45 5151.75 2086.62 5038.34 4892.22 3882.94 4015.46 3985.45 6493.48
#  4430.49 5428.56 2914.3  6028.93 3791.16 3872.54 2621.96 4526.12 2499.
#  2417.11 5505.97 5134.71 5794.31 4329.5  4923.27 4027.56 3753.31 5868.84
#  2968.2  3511.71 4307.72 3403.93 4722.68 3580.93 5042.08 6133.65 4999.76
#  2451.63 4355.96 3495.35 5043.32 3915.71 4745.47 4944.4  5571.47 3540.91
#  4435.54 5359.38 4290.61 3787.26 3927.94 4805.17 2608.53 2497.72 3448.03
#  3465.03 3501.94 4209.18 3518.13 5185.62 2599.86 2728.63 2961.76 3855.63
#  5343.05 4158.47 3796.71 2648.85 2656.26 2724.82 4015.3  3722.8  4172.08
#  4246.55 2109.01 3811.73 2980.23 3516.18 3344.42 4901.86 4683.04 5973.63
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
#from sklearn.metrics import r2_score
rfr = RandomForestRegressor(random_state=8)
rfr.fit(x_train,y_train)
y_pred_rfr = rfr.predict(x_test)
print(y_pred_rfr)
print(r2_score(y_test,y_pred_rfr))
# Out:
# [3011.8054 4233.6255 5226.014  4724.8783 4694.8381 4964.6939 4518.7255
#  2390.4887 4066.5599 4940.9182 5169.2642 3719.5191 4484.7246 4871.6374
#  4377.8851 2640.0886 4938.4475 3946.2739 3239.3177 4247.0534 4324.6698
#  4822.5186 5045.7439 4513.6071 5505.8952 4246.9763 4448.2572 4605.425
#  4031.8236 3853.2603 4674.8154 4557.8681 5827.2708 3646.2747 3628.489
#  4051.833  4256.4653 4059.4923 2630.9912 5564.6639 4826.1269 3736.0934
#  4802.8747 4384.2775 4297.6366 3344.7459 5276.5407 2761.1758 3043.9833
#  4038.7145 3188.9002 4209.1338 5026.4975 3137.5327 3549.1538 5183.6862
#  2896.3628 5103.2138 4628.7574 2851.1797 2575.4905 5219.137  3639.7802
#  2691.4432 5188.2469 5315.3625 4386.3945 4044.3538 3138.2775 3867.5344
#  3922.0343 4689.49   5094.6887 4538.2426 4049.0184 3385.495  4320.7435
#  4896.1965 3195.1106 4564.2057 3847.2699 4624.561  4028.759  5894.5719
#  3893.908  4751.8163 4953.4957 3131.8859 5062.7053 4052.7696 3532.4874
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
#from sklearn.metrics import r2_score
rfr = RandomForestRegressor(random_state=8)
rfr.fit(x_train,y_train)
y_pred_rfr = rfr.predict(x_train)
print(y_pred_rfr)
print(r2_score(y_train,y_pred_rfr))
# Out:
# [2718.4332 5720.2438 4092.4345 3005.5292 3253.0045 4688.6201 5522.8785
#  4112.3315 5711.0909 3411.4948 4343.3962 5241.5062 4023.6558 2596.0906
#  4994.935  3879.5505 3362.951  5647.9154 3547.4878 3016.0474 4956.6827
#  4734.9677 4119.6283 3943.735  4505.1341 4807.5481 3403.7707 5733.1407
#  3544.8344 3479.3338 4244.5232 4706.5117 4000.975  4209.2546 2277.9881
#  4480.311  2711.9566 5153.9049 2087.6298 5027.7606 4877.6972 3898.5316
#  3986.8617 4027.3391 6406.2559 4359.1807 5402.6833 2848.2345 5906.0665
#  3787.4468 3816.7614 2667.7581 4608.4032 2556.6465 2457.9639 5465.9829
#  5224.5804 5771.6593 4310.9849 4900.2294 3966.8622 3741.8368 5867.0313
#  2973.6639 3569.0159 4366.9042 3444.7763 4649.9465 3475.7322 5003.5276
#  6100.3219 5040.7553 2504.1573 4350.7545 3527.9728 4996.3829 3847.5249
#  4774.6382 4891.5068 5480.6547 3552.4528 4378.5307 5288.4836 4324.4722
#  3789.5572 3945.398  4821.4488 2648.2432 2473.5906 3466.2171 3454.9324
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
import numpy as np
from tabulate import tabulate
# Define regression models
models = {
    "Linear Regression": LinearRegression(),
    "Decision tree": DecisionTreeRegressor(random_state=8),
    "Random Forest": RandomForestRegressor(n_estimators=100,random_state=8),
    
}
# Dictionary to store results
results = []

# Train and evaluate models
for model_name, model in models.items():
    model.fit(x_train, y_train)  # Train
    y_pred = model.predict(x_test)  # Predict

    # Compute regression metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Append results to list
    results.append({"Model": model_name, "MAE": mae, "MSE": mse, "RMSE": rmse, "R² Score": r2})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Display results

print(tabulate(df_results.T,tablefmt="simple_grid"))
# Out:
# ┌──────────┬────────────────────┬────────────────────┬────────────────────┐
# │ Model    │ Linear Regression  │ Decision tree      │ Random Forest      │
# ├──────────┼────────────────────┼────────────────────┼────────────────────┤
# │ MAE      │ 332.1437694073288  │ 182.19429999999997 │ 94.42972300000044  │
# ├──────────┼────────────────────┼────────────────────┼────────────────────┤
# │ MSE      │ 127509.76507879289 │ 53191.118774999995 │ 13147.987945643847 │
# ├──────────┼────────────────────┼────────────────────┼────────────────────┤
# │ RMSE     │ 357.08509501068914 │ 230.6319985929966  │ 114.66467610229336 │
# ├──────────┼────────────────────┼────────────────────┼────────────────────┤
# │ R² Score │ 0.8141864738600042 │ 0.9224872751290332 │ 0.9808401027143562 │
# └──────────┴────────────────────┴────────────────────┴────────────────────┘

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("rfr.pkl","wb")
pickle.dump(rfr, pickle_out)
pickle_out.close()

# %%
rfr.predict([['2','7063','76','10','29.84','0']])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2718.4332])

# %%
# !pip install streamlit

# %% [markdown]
# # Conclusion :
#
# In this project, we used data about buildings and environmental factors to predict energy consumption. By analyzing details like building type, size, number of people, appliances, temperature, and the day of the week, we built a model to estimate how much energy a building will use.
#
# This helps us understand energy usage patterns and find ways to save energy and reduce costs in different buildings.
